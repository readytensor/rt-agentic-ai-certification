# %% [markdown]
# # Week 2 Assignment: Prompts Embeddings and RAG
#
# ## Part 1: Reflection Questions
#
# Answer the following questions based on the concepts covered in the lecture:

# %% [markdown]
# 1. **Prompt Understanding**:
#    Analyze at least three different types of prompts (e.g., zero-shot, few-shot, Chain-of-Thought) and explain when each would be most effective. Provide specific use cases for each type.
#
#    *Your Answer Here:*

# %% [markdown]
# 2. **System vs. User Prompts**:
#    Explain in your own understanding, the fundamental differences between system prompts and user prompts. How do they interact, and what specific functions does each serve in guiding an AI's behavior?
#
#    *Your Answer Here:*

# %% [markdown]
# 3. **Vector Embeddings Concept**:
#    Explain in your own words what vector embeddings are and why they are critical for modern AI applications. How do embeddings capture semantic meaning, and why is this important?
#
#    *Your Answer Here:*

# %% [markdown]
# 4. **RAG Architecture Analysis**:
#    Describe the core components of a Retrieval-Augmented Generation (RAG) system and explain how each component contributes to improving AI responses. What specific advantages does RAG offer over using a base LLM without retrieval?
#
#    *Your Answer Here:*

# %% [markdown]
# ## Part 2: Prompt Engineering Exercises
#
# For each of the following scenarios, craft both a system prompt and a user prompt that would effectively guide an AI to produce the desired output. Explain your reasoning behind each design choice.

# %% [markdown]
# 1. **Customer Support Assistant**:
#    Design prompts for an AI that needs to help customers troubleshoot technical issues with a smartphone, maintaining a helpful but concise tone.
#
#    *Your Answer Here:*

# %% [markdown]
# 2. **Creative Writing Coach**:
#    Design prompts for an AI that provides constructive feedback on short stories, focusing on plot development, character arcs, and descriptive language.
#
#    *Your Answer Here:*

# %% [markdown]
# 3. **Financial Advisor**:
#    Design prompts for an AI that offers personalized investment advice while maintaining appropriate disclaimers and avoiding specific stock recommendations.
#
#    *Your Answer Here:*

# %% [markdown]
# 4. **Sensitive Topic Navigation**:
#    Design prompts for an AI that needs to discuss political topics in an educational context while maintaining neutrality and avoiding bias.
#
#    *Your Answer Here:*
